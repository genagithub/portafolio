# %% [markdown]
# #### Proyecto 1
# Uso del Dataset 'Titanic', donde describimos las características numéricas y categóricas de la variable objetivo, y cómo estas influyen en su clase asociada. Por último, se elabora un dashboard que muestra el desempeño de un modelo de clasificación desarrollado.
# _________________________________________________________________________________________________________

# %% [markdown]
# #### Proyecto 2
# Ejemplo que utiliza el popular Dataset 'Tips', donde introducimos la regresión lineal y las suposiciones que requiere su modelado. Al final, se genera un dashboard que ilustra un EDA(gráficos de distribución, pruebas de normalidad, correlación) y el modelo lineal.
# _________________________________________________________________________________________________________

# %% [markdown]
# #### Proyecto 3
# En esta ocasión se obtiene la información de una Database, más precisamente de MySQL. Se realizan consultas con el fin de conseguir los datos de diferentes entidades, en este caso de componentes de negocio para elaborar un análisis sobre los que obtuvieron mejores KPIs.
# _________________________________________________________________________________________________________

# %% [markdown]
# #### Proyecto 4
#  Al igual que el segundo ejemplo, el Dataset empleado es 'Iris', muy conocido entre la comunidad. Se crea una interfaz interactiva cuya función es graficar los datos que le enviamos por medio de una entrada y asignarles su clase determinada por un clasificador.
# _________________________________________________________________________________________________________

# %% [markdown]
# #### Proyecto 5
# Ejemplo basado analizar la distribución de frecuencia en las distintas variables categóricas(nominales y ordinales) y en la implementación de Bootsrapping mediante un metamodelo de Bagging. Como en todos los otros casos, se realiza una visualización final.
# _________________________________________________________________________________________________________

# %% [markdown]
# #### Proyecto 6
# Mayor volumen de datos implementado entre los ejemplos, se desarrolla un aprendizaje supervisado y no supervisado, profundizamos en el metaaprendizaje y nos apoyamos en una función que ayudará a asignar los hiperparámetros óptimos del modelo.
# _________________________________________________________________________________________________________

# %% [markdown]
# #### Proyecto 7
# Análisis profundo de series temporales, se observan diferentes conceptos de esta área para determinar la creación de un modelo ajustado adecuadamente que sea capaz de realizar un un pronóstico funcional según los insights de las distintas series examinadas.
# _________________________________________________________________________________________________________

# %% [markdown]
# #### Proyecto 8
# Web Scraping, se utiliza la librería Selenium y el manejo de excepciones con el objetivo de interactuar con Linkedin y extraer los datos provenientes que nos interesan para su posterior organización, limpieza y visualización, se otorga una opinión final.
# _________________________________________________________________________________________________________
